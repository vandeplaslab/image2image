# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
from image2image_io.readers import get_simple_reader
from image2image_io.readers._czi import CziFile, get_czi_thumbnail
from image2image_io.readers.czi_reader import CziImageReader
from image2image_io.writers import write_ome_tiff_from_array
from pathlib import Path

import matplotlib.pyplot as plt

# %%
path = r"Y:\hubmap\projects\eye_biomic\white_male\202300549M88\nerve-pos\postaf\202300549M_PostAF_Nerve_Retina_Pos.czi"
czi = CziImageReader(path, init_pyramid=False, auto_pyramid=False)
# data = czi.fh.asarray_alt()
# data.shape, czi.fh.axes, czi.pyramid[0].shape

# %%
czi = CziFile(path)

# %%
block = czi.filtered_subblock_directory[10]
de = block.dimension_entries[2]
de.size
# Out:
# 1

# %%
dir(block.dimension_entries[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  'dimension',
#  'size',
#  'start',
#  'start_coordinate',
#  'stored_size']

# %%
# Out:
# 'M'
